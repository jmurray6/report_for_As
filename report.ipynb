# %% [markdown]
# Concurrent Sessions Report
# ========
#
# All visualizations were made by pulling data from the last month without test sessions and without vendor “DEV”.

# %% [markdown]
# Scan Timing Percentile Pies
# ---------
#
# What percentage of scans taken in the last month had another scan within X minutes afterwards?

# %%
from timing_pies import generate_pies

excludeTOP = False

generate_pies("ALL", excludeTOP)

# %% [markdown]
# Scans by Time Bucket
# ----------
#
# What time of day did scans happen across the last month? (Does not indicate scans happening at the same time, but time of day across all days)
#
# *(Y axis changes)*

# %%
from timing_bars import generate_bars

excludeTOP = False

generate_bars("ALL", excludeTOP)
generate_bars("TOP", excludeTOP)
generate_bars("IRS", excludeTOP)
generate_bars("LOH", excludeTOP)
generate_bars("NLL", excludeTOP)

# %% [markdown]
# Scans by Time Bucket for All Vendors EXCEPT "TOP"
# ---

# %%
from timing_bars import generate_bars

excludeTOP = True

generate_bars("ALL", excludeTOP)

# %% [markdown]
# Close Scans by Time Bucket
# ---
#
# When scans happen close together, when do they happen and how long is there between scans? This visualization represents each instance of a scan that had another scan after it, within 15 minutes. The colors represent whether that scan came 0-5, 5-10, or 10-15 minutes after.
#
# *This is currently divided by periods of every 2 hours for the week, but we can easily change it to be broader or more specific.*

# %%
from itemized_bars import generate_itemized_bars

excludeTOP = False

generate_itemized_bars("ALL", excludeTOP)

# %% [markdown]
# Close Scans by Time Bucket for All Vendors EXCEPT "TOP"
# ---

# %%
from itemized_bars import generate_itemized_bars

excludeTOP = True

generate_itemized_bars("ALL", excludeTOP)
